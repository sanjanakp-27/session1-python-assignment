# %% [markdown]
# assignment

# %% [markdown]
# task 1

# %% [markdown]
# Jupyter Notebook: analytics_intro.ipynb

# %%
name = "Sanjana"
favorite_app = "Instagram"

print("My name is:", name)
print("My favorite app is:", favorite_app)
# Out:
# My name is: Sanjana
# My favorite app is: Instagram

# %%
import datetime 

current_year = datetime.datetime.now().year 
print("current year :",current_year)
# Out:
# current year : 2026

# %% [markdown]
# hello_app.py

# %%
print("welcome to data analytics with python !")
# Out:
# welcome to data analytics with python !
